# %%
import json

# %%
with open(f"test_" + 'metadata.json', "r", encoding="ISO-8859-1") as file:
            test_meta = json.load(file)
        
test_root = "D:/herbarium2022/test_images"

test_img_dirs = [ image['file_name'] for image in test_meta]

with open('D:/test_img_files.txt', 'w') as outfile:
    outfile.write('\n'.join(i for i in test_img_dirs))

# %%
with open(f"train_" + 'metadata.json', "r", encoding="ISO-8859-1") as file:
            train_meta = json.load(file)
# Out:
# [{'image_id': '00000__001',
#   'file_name': '000/00/00000__001.jpg',
#   'license': 0},
#  {'image_id': '00000__002',
#   'file_name': '000/00/00000__002.jpg',
#   'license': 0},
#  {'image_id': '00000__003',
#   'file_name': '000/00/00000__003.jpg',
#   'license': 0},
#  {'image_id': '00000__004',
#   'file_name': '000/00/00000__004.jpg',
#   'license': 0},
#  {'image_id': '00000__005',
#   'file_name': '000/00/00000__005.jpg',
#   'license': 0},
#  {'image_id': '00000__006',
#   'file_name': '000/00/00000__006.jpg',
#   'license': 0},
#  {'image_id': '00000__007',
#   'file_name': '000/00/00000__007.jpg',
#   'license': 0},
#  {'image_id': '00000__008',
#   'file_name': '000/00/00000__008.jpg',
#   'license': 0},
#  {'image_id': '00000__009',
#   'file_name': '000/00/00000__009.jpg',
#   'license': 0},
#  {'image_id': '00000__011',
#   'file_name': '000/00/00000__011.jpg',
#   'license': 0},
#  {'image_id': '00000__012',
#   'file_name': '000/00/00000__012.jpg',
# ...

# %%
train_img_dirs = [ image['file_name'] for image in train_meta['images']]

with open('D:/train_img_files.txt', 'w') as outfile:
    outfile.write('\n'.join(i for i in train_img_dirs))

# %%
os.cpucount
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 os.cpucount
#
# AttributeError: module 'os' has no attribute 'cpucount'
